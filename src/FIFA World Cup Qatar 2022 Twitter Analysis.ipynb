# %%
# Import basic libraries
import pandas as pd
import numpy as np
import altair as alt

# %%
#!pip install snscrape

# %%
# librerías
import snscrape.modules.twitter as sntwitter

# %%
# %%time

# Parámetros
tweets_list_mundial3 = []
maxTweets_mundial3 = 250_000
date_initial = "2022-11-20"

# Get tweets
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('#WorldcupQatar2022 since:'+date_initial).get_items()): # se puede añadir esto --> since:'+date_initial
        if i>maxTweets_mundial3-1:
            break
        tweets_list_mundial3.append([tweet.user.username, tweet.date, tweet.id, tweet.content, tweet.url, tweet.lang,
                    tweet.hashtags, tweet.likeCount, tweet.replyCount, tweet.retweetCount, tweet.quoteCount, 
                    tweet.mentionedUsers, tweet.coordinates, tweet.place, tweet.cashtags, tweet.media])
        # Otra info que puede sernos útil: tweet.media,  tweet.url
# Out:
# CPU times: total: 20 s
# Wall time: 2h 8min 23s

# %%
# Pandas dataframe con tweets de los tres presidentes relacionados con el Covid-19
column_names = ("username","date","id","content","url","language","hashtags",
                "likes_count","reply_count","retweet_count","quote_count","mentioned_users","coordinates","place","cashtags", "media")
df = pd.DataFrame(tweets_list_mundial3, columns=column_names)
df
# Out:
#                username                      date                   id  \
# 0           0KBaila_Q45 2022-11-27 04:16:55+00:00  1596719695595732993
# 1              SoheBoss 2022-11-27 04:16:51+00:00  1596719678050607104
# 2         AdrielVilla77 2022-11-27 04:16:48+00:00  1596719666172289024
# 3                 theUG 2022-11-27 04:16:40+00:00  1596719631317729282
# 4       DeccanChronicle 2022-11-27 04:16:36+00:00  1596719612984692736
# ...                 ...                       ...                  ...
# 184235   Yerdensertorta 2022-11-20 00:06:46+00:00  1594120026226798594
# 184236  kopibukudanpena 2022-11-20 00:04:40+00:00  1594119499208278016
# 184237       i8mikehunt 2022-11-20 00:03:35+00:00  1594119227065380864
# 184238             GIMS 2022-11-20 00:00:10+00:00  1594118367866232834
# 184239     melvinrocker 2022-11-20 00:00:01+00:00  1594118328850665472
#
#                                                   content  \
# 0       Apakah Argentina bisa melaju ke final dan MESS...
# 1       @NeblioTeam @TerraRebels #WorldcupQatar2022 #B...
# 2       Toda copa a musa volta com a melhor música ❤️☀...
# 3       MARADONA FLYING KNEE \n#FIFAWorldCup #Worldcup...
# 4       With the @FIFAcom #WorldcupQatar2022 underway ...
# ...                                                   ...
# 184235  🏆💔 Dünya Kupasını kaçıracak futbolcular.\n\nFr...
# 184236                       Marhabban #WorldcupQatar2022
# 184237  In lieu of the alcohol ban, Qatar world cup of...
# 184238  Fin du suspense je suis heureux de vous annonc...
# 184239  My predictions for the @MLS Qatar Quest Bracke...
#
#                                                       url language  \
# 0       https://twitter.com/0KBaila_Q45/status/1596719...       in
# 1       https://twitter.com/SoheBoss/status/1596719678...      qme
# 2       https://twitter.com/AdrielVilla77/status/15967...       pt
# 3       https://twitter.com/theUG/status/1596719631317...       en
# 4       https://twitter.com/DeccanChronicle/status/159...       en
# ...                                                   ...      ...
# 184235  https://twitter.com/Yerdensertorta/status/1594...       tr
# 184236  https://twitter.com/kopibukudanpena/status/159...       hu
# 184237  https://twitter.com/i8mikehunt/status/15941192...       en
# 184238  https://twitter.com/GIMS/status/15941183678662...       fr
# 184239  https://twitter.com/melvinrocker/status/159411...       en
#
#                                                  hashtags  likes_count  \
# 0                                     [WorldcupQatar2022]            0
# 1                            [WorldcupQatar2022, Bitcoin]            0
# 2       [Wakawaka, shakira, CopadoMundo, WorldcupQatar...            0
# 3                       [FIFAWorldCup, WorldcupQatar2022]            0
# 4                        [WorldcupQatar2022, Inoxcinemas]            0
# ...                                                   ...          ...
# 184235                                [WorldcupQatar2022]            4
# 184236                                [WorldcupQatar2022]            0
# 184237  [Budweiser, budweiserworldcup, FAIL, blunder, ...            0
# 184238                                [WorldcupQatar2022]        23111
# 184239  [WorldCup2022, MLS, Qatar, QatarWorldCup2022, ...            0
#
#         reply_count  retweet_count  quote_count  \
# 0                 0              0            0
# 1                 0              0            0
# 2                 0              0            0
# 3                 0              0            0
# 4                 0              0            0
# ...             ...            ...          ...
# 184235            0              0            0
# 184236            0              0            0
# 184237            0              0            0
# 184238         1624           2495          758
# 184239            0              0            0
#
#                                           mentioned_users coordinates place  \
# 0                                                    None        None  None
# 1       [https://twitter.com/NeblioTeam, https://twitt...        None  None
# 2                                                    None        None  None
# 3                                                    None        None  None
# 4                           [https://twitter.com/FIFAcom]        None  None
# ...                                                   ...         ...   ...
# 184235                                               None        None  None
# 184236                                               None        None  None
# 184237                                               None        None  None
# 184238                                               None        None  None
# 184239  [https://twitter.com/MLS, https://twitter.com/...        None  None
#
#        cashtags                                              media
# 0          None                                               None
# 1          None                                               None
# 2          None  [Video(thumbnailUrl='https://pbs.twimg.com/ext...
# 3          None  [Video(thumbnailUrl='https://pbs.twimg.com/ext...
# 4          None                                               None
# ...         ...                                                ...
# 184235     None  [Photo(previewUrl='https://pbs.twimg.com/media...
# 184236     None                                               None
# 184237     None                                               None
# 184238     None                                               None
# 184239     None  [Photo(previewUrl='https://pbs.twimg.com/media...
#
# [184240 rows x 16 columns]

# %%
df.to_csv("data/FIFA World Cup Qatar 2022 Twitter_v2.csv")

# %%
df.dtypes
# Out:
# username                        object
# date               datetime64[ns, UTC]
# id                               int64
# content                         object
# url                             object
# language                        object
# hashtags                        object
# likes_count                      int64
# reply_count                      int64
# retweet_count                    int64
# quote_count                      int64
# mentioned_users                 object
# coordinates                     object
# place                           object
# cashtags                        object
# media                           object
# dtype: object

# %%
df.isnull().sum()
# Out:
# username                0
# date                    0
# id                      0
# content                 0
# url                     0
# language                0
# hashtags               11
# likes_count             0
# reply_count             0
# retweet_count           0
# quote_count             0
# mentioned_users    161225
# coordinates        173017
# place              173018
# cashtags           183841
# media              122800
# dtype: int64

# %% [markdown]
# ## In which language are most of the world cup tweets made?

# %%
# Número de comentarios por idioma
print("\nTweets by language, from November 20, 2022 to November 26, 2022:\n")
df_language=pd.DataFrame(df['language'].value_counts()).reset_index().rename(columns={'index':'language', 'language':'tweets'})


df_language.head()
# Out:
# Tweets by language, from November 20, 2022 to November 26, 2022:
#   language  tweets
# 0       en   87445
# 1       pt   22631
# 2       es   16353
# 3       fr    8836
# 4       ja    7613

# %%
#interpret language code
tables = pd.read_csv("https://datahub.io/core/language-codes/r/language-codes.csv")
tables.rename(columns = {'alpha2':'language'}, inplace = True)
tables.rename(columns = {'English':'language_comp'}, inplace = True)
tables.head()
# Out:
#   language language_comp
# 0       aa          Afar
# 1       ab     Abkhazian
# 2       ae       Avestan
# 3       af     Afrikaans
# 4       ak          Akan

# %%
tables.shape
# Out:
# (184, 2)

# %%
n = len(pd.unique(tables['language']))
print(n)
# Out:
# 184

# %%
#interpret language code

df_language= pd.merge(df_language, tables, on="language", how="inner")
df_language.head()
#pd.merge(df_language, tables[["language", "language_comp"]],  how="left", on="language")
# Out:
#   language  tweets       language_comp
# 0       en   87445             English
# 1       pt   22631          Portuguese
# 2       es   16353  Spanish; Castilian
# 3       fr    8836              French
# 4       ja    7613            Japanese

# %%
# language, general plot
alt.Chart(df_language).mark_bar().encode(
    alt.X('language_comp',  sort='-y',  title="Language"),
    alt.Y('tweets', title="Tweets"),
    alt.Color('language_comp', legend=None),
    tooltip=['language_comp', 'tweets']
).properties(title="Tweets by language")
# Out:
# alt.Chart(...)

# %%
nr = 15
top = df_language.sort_values(by='tweets', ascending=False).head(nr)


alt.Chart(
    top,
    title='Top {} languages in tweets about the 2022 World Cup'.format(nr)
).mark_bar().encode(
    x=alt.X('language_comp:N', sort=alt.EncodingSortField(field="tweets", op="count", order='descending'), title="Language"),
    y=alt.Y('tweets', title="Tweets"),
)
# Out:
# alt.Chart(...)

# %%
top
# Out:
#    language  tweets            language_comp
# 0        en   87445                  English
# 1        pt   22631               Portuguese
# 2        es   16353       Spanish; Castilian
# 3        fr    8836                   French
# 4        ja    7613                 Japanese
# 5        ar    7191                   Arabic
# 6        tr    3666                  Turkish
# 7        pl    2775                   Polish
# 8        it    1849                  Italian
# 9        nl    1071           Dutch; Flemish
# 10       de     762                   German
# 11       fa     680                  Persian
# 12       el     670    Greek, Modern (1453-)
# 13       tl     656                  Tagalog
# 14       ht     494  Haitian; Haitian Creole

# %% [markdown]
# ## Where are the people tweeting about the world cup?

# %%
df_map=df.loc[df['coordinates'].notnull()]

# %%
df_map.head()
# Out:
#             username                      date                   id  \
# 11   Arv_Ind_Chauhan 2022-11-27 04:14:24+00:00  1596719061265567744
# 14         Ger_mannn 2022-11-27 04:13:36+00:00  1596718858957914112
# 91   GustavoEscobarG 2022-11-27 04:01:11+00:00  1596715734188466176
# 132          macec88 2022-11-27 03:53:05+00:00  1596713694989537280
# 143   preethisadasiv 2022-11-27 03:51:31+00:00  1596713303186677760
#
#                                                content  \
# 11   That lucky 🐐 made it to feature page of @ttind...
# 14   You can spit in a young girls face you can red...
# 91   Tremendo baile en el  #EcuadorvsNetherlands va...
# 132  Just a couple of mate from High School still h...
# 143  What do you call that?!!😇\n#Messi𓃵\n#Argentina...
#
#                                                    url language  \
# 11   https://twitter.com/Arv_Ind_Chauhan/status/159...       en
# 14   https://twitter.com/Ger_mannn/status/159671885...       en
# 91   https://twitter.com/GustavoEscobarG/status/159...       es
# 132  https://twitter.com/macec88/status/15967136949...       en
# 143  https://twitter.com/preethisadasiv/status/1596...       en
#
#                                               hashtags  likes_count  \
# 11                          [GOAT𓃵, WorldcupQatar2022]            1
# 14                                 [WorldcupQatar2022]            0
# 91   [EcuadorvsNetherlands, ecu, WorldcupQatar2022,...            0
# 132                                [WorldCupQatar2022]            5
# 143  [Messi𓃵, ArgentinavsMexico, WorldcupQatar2022,...            3
#
#      reply_count  retweet_count  quote_count  \
# 11             0              0            0
# 14             0              0            0
# 91             0              0            0
# 132            0              0            0
# 143            1              0            0
#
#                                        mentioned_users  \
# 11   [https://twitter.com/ttindia, https://twitter....
# 14   [https://twitter.com/Carra23, https://twitter....
# 91               [https://twitter.com/fifaworldcup_es]
# 132  [https://twitter.com/FedSquare, https://twitte...
# 143                                               None
#
#                                            coordinates  \
# 11   Coordinates(longitude=80.658613, latitude=26.6...
# 14   Coordinates(longitude=-6.6960971, latitude=53....
# 91   Coordinates(longitude=-80.4676050033072, latit...
# 132  Coordinates(longitude=144.96796240787086, lati...
# 143  Coordinates(longitude=76.7996471, latitude=8.3...
#
#                                                  place cashtags  \
# 11   Place(fullName='Lucknow, India', name='Lucknow...     None
# 14   Place(fullName='Louth, Ireland', name='Louth',...     None
# 91   Place(fullName='Guayaquil, Ecuador', name='Gua...     None
# 132  Place(fullName='Federation Square', name='Fede...     None
# 143  Place(fullName='Trivandrum, India', name='Triv...     None
#
#                                                  media
# 11   [Photo(previewUrl='https://pbs.twimg.com/media...
# 14                                                None
# 91   [Video(thumbnailUrl='https://pbs.twimg.com/ext...
# 132  [Photo(previewUrl='https://pbs.twimg.com/media...
# 143  [Video(thumbnailUrl='https://pbs.twimg.com/ext...

# %%
print("There are {} tweets with coordinates of the place of publication".format(df_map.shape[0]))
# Out:
# There are 11223 tweets with coordinates of the place of publication

# %%
df_map.head()
# Out:
#             username                      date                   id  \
# 11   Arv_Ind_Chauhan 2022-11-27 04:14:24+00:00  1596719061265567744
# 14         Ger_mannn 2022-11-27 04:13:36+00:00  1596718858957914112
# 91   GustavoEscobarG 2022-11-27 04:01:11+00:00  1596715734188466176
# 132          macec88 2022-11-27 03:53:05+00:00  1596713694989537280
# 143   preethisadasiv 2022-11-27 03:51:31+00:00  1596713303186677760
#
#                                                content  \
# 11   That lucky 🐐 made it to feature page of @ttind...
# 14   You can spit in a young girls face you can red...
# 91   Tremendo baile en el  #EcuadorvsNetherlands va...
# 132  Just a couple of mate from High School still h...
# 143  What do you call that?!!😇\n#Messi𓃵\n#Argentina...
#
#                                                    url language  \
# 11   https://twitter.com/Arv_Ind_Chauhan/status/159...       en
# 14   https://twitter.com/Ger_mannn/status/159671885...       en
# 91   https://twitter.com/GustavoEscobarG/status/159...       es
# 132  https://twitter.com/macec88/status/15967136949...       en
# 143  https://twitter.com/preethisadasiv/status/1596...       en
#
#                                               hashtags  likes_count  \
# 11                          [GOAT𓃵, WorldcupQatar2022]            1
# 14                                 [WorldcupQatar2022]            0
# 91   [EcuadorvsNetherlands, ecu, WorldcupQatar2022,...            0
# 132                                [WorldCupQatar2022]            5
# 143  [Messi𓃵, ArgentinavsMexico, WorldcupQatar2022,...            3
#
#      reply_count  retweet_count  quote_count  \
# 11             0              0            0
# 14             0              0            0
# 91             0              0            0
# 132            0              0            0
# 143            1              0            0
#
#                                        mentioned_users  \
# 11   [https://twitter.com/ttindia, https://twitter....
# 14   [https://twitter.com/Carra23, https://twitter....
# 91               [https://twitter.com/fifaworldcup_es]
# 132  [https://twitter.com/FedSquare, https://twitte...
# 143                                               None
#
#                                            coordinates  \
# 11   Coordinates(longitude=80.658613, latitude=26.6...
# 14   Coordinates(longitude=-6.6960971, latitude=53....
# 91   Coordinates(longitude=-80.4676050033072, latit...
# 132  Coordinates(longitude=144.96796240787086, lati...
# 143  Coordinates(longitude=76.7996471, latitude=8.3...
#
#                                                  place cashtags  \
# 11   Place(fullName='Lucknow, India', name='Lucknow...     None
# 14   Place(fullName='Louth, Ireland', name='Louth',...     None
# 91   Place(fullName='Guayaquil, Ecuador', name='Gua...     None
# 132  Place(fullName='Federation Square', name='Fede...     None
# 143  Place(fullName='Trivandrum, India', name='Triv...     None
#
#                                                  media  \
# 11   [Photo(previewUrl='https://pbs.twimg.com/media...
# 14                                                None
# 91   [Video(thumbnailUrl='https://pbs.twimg.com/ext...
# 132  [Photo(previewUrl='https://pbs.twimg.com/media...
# 143  [Video(thumbnailUrl='https://pbs.twimg.com/ext...
#
#                                      coordinates_clean
# 11   Coordinates(longitude=80.658613, latitude=26.6...
# 14   Coordinates(longitude=-6.6960971, latitude=53....
# 91   Coordinates(longitude=-80.4676050033072, latit...
# 132  Coordinates(longitude=144.96796240787086, lati...
# 143  Coordinates(longitude=76.7996471, latitude=8.3...

# %% [markdown]
# ## Which days have had the most tweets about the world cup?

# %%
df['date_only'] = df['date'].dt.date

# %%
df.head()
# Out:
#           username                      date                   id  \
# 0      0KBaila_Q45 2022-11-27 04:16:55+00:00  1596719695595732993
# 1         SoheBoss 2022-11-27 04:16:51+00:00  1596719678050607104
# 2    AdrielVilla77 2022-11-27 04:16:48+00:00  1596719666172289024
# 3            theUG 2022-11-27 04:16:40+00:00  1596719631317729282
# 4  DeccanChronicle 2022-11-27 04:16:36+00:00  1596719612984692736
#
#                                              content  \
# 0  Apakah Argentina bisa melaju ke final dan MESS...
# 1  @NeblioTeam @TerraRebels #WorldcupQatar2022 #B...
# 2  Toda copa a musa volta com a melhor música ❤️☀...
# 3  MARADONA FLYING KNEE \n#FIFAWorldCup #Worldcup...
# 4  With the @FIFAcom #WorldcupQatar2022 underway ...
#
#                                                  url language  \
# 0  https://twitter.com/0KBaila_Q45/status/1596719...       in
# 1  https://twitter.com/SoheBoss/status/1596719678...      qme
# 2  https://twitter.com/AdrielVilla77/status/15967...       pt
# 3  https://twitter.com/theUG/status/1596719631317...       en
# 4  https://twitter.com/DeccanChronicle/status/159...       en
#
#                                             hashtags  likes_count  \
# 0                                [WorldcupQatar2022]            0
# 1                       [WorldcupQatar2022, Bitcoin]            0
# 2  [Wakawaka, shakira, CopadoMundo, WorldcupQatar...            0
# 3                  [FIFAWorldCup, WorldcupQatar2022]            0
# 4                   [WorldcupQatar2022, Inoxcinemas]            0
#
#    reply_count  retweet_count  quote_count  \
# 0            0              0            0
# 1            0              0            0
# 2            0              0            0
# 3            0              0            0
# 4            0              0            0
#
#                                      mentioned_users coordinates place  \
# 0                                               None        None  None
# 1  [https://twitter.com/NeblioTeam, https://twitt...        None  None
# 2                                               None        None  None
# 3                                               None        None  None
# 4                      [https://twitter.com/FIFAcom]        None  None
#
#   cashtags                                              media   date_only
# 0     None                                               None  2022-11-27
# 1     None                                               None  2022-11-27
# 2     None  [Video(thumbnailUrl='https://pbs.twimg.com/ext...  2022-11-27
# 3     None  [Video(thumbnailUrl='https://pbs.twimg.com/ext...  2022-11-27
# 4     None                                               None  2022-11-27

# %%
df["date_only"] = pd.to_datetime(df["date_only"])

# %%
df_date = df.groupby(df['date_only'].dt.date).size().reset_index(name='Count')
df_date.head()
# Out:
#     date_only  Count
# 0  2022-11-20   7947
# 1  2022-11-21   6266
# 2  2022-11-22  19127
# 3  2022-11-23  33918
# 4  2022-11-24  52321

# %%
df_date["date_only"] = pd.to_datetime(df_date["date_only"])

# %%
alt.Chart(df_date).mark_bar(size=25).encode(
    alt.X('date_only', title="Date"),
    alt.Y('Count:Q', title="Tweets"),
    alt.Color('date_only'),
    tooltip=['date_only', 'Count']
).properties(title="Number of tweets per day")
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Which users have the most likes?

# %%
print("\nUsers with the most likes on their tweets, from November 20, 2022 to November 26, 2022:\n")
df_user=df.pivot_table(values='likes_count', index = 'username', aggfunc= 'sum')
df_user=df_user.sort_values(by=['likes_count'], ascending=False)
df_user.head(15)
# Out:
# Users with the most likes on their tweets, from November 20, 2022 to November 26, 2022:
#                  likes_count
# username
# Carra23               131502
# beINSPORTS             84088
# Saudi_Gazette          35543
# anandmahindra          35161
# CBF_Futebol            28174
# BlazquezFont           23761
# GIMS                   23111
# SobugMessi10jr         20330
# 1209msg                17223
# sniper_ma              10449
# HackedOffHugh          10157
# CMonteroOficial         9585
# gilabola_ina            8721
# SebastianMila11         8011
# FiercePC                7981

# %% [markdown]
# # Sentiment Analysis Tweets in english

# %% [markdown]
# ## Remove punctuation marks

# %%
#library that contains punctuation
import string
signos_puntuacion = string.punctuation
signos_puntuacion = signos_puntuacion.replace("#", "")  # quitar '#' de hashtags 
signos_puntuacion = signos_puntuacion.replace("@", "")  # quitar '@' de cuentas
signos_puntuacion
# Out:
# '!"$%&\'()*+,-./:;<=>?[\\]^_`{|}~'

# %%
#defining the function to remove punctuation
def remove_punctuation(text):
    punctuationfree="".join([i for i in text if i not in signos_puntuacion])
    return punctuationfree

#storing the puntuation free text
df['tweet_clean'] = df['content'].apply(lambda x:remove_punctuation(x))
df.head()
# Out:
#           username                      date                   id  \
# 0      0KBaila_Q45 2022-11-27 04:16:55+00:00  1596719695595732993
# 1         SoheBoss 2022-11-27 04:16:51+00:00  1596719678050607104
# 2    AdrielVilla77 2022-11-27 04:16:48+00:00  1596719666172289024
# 3            theUG 2022-11-27 04:16:40+00:00  1596719631317729282
# 4  DeccanChronicle 2022-11-27 04:16:36+00:00  1596719612984692736
#
#                                              content  \
# 0  Apakah Argentina bisa melaju ke final dan MESS...
# 1  @NeblioTeam @TerraRebels #WorldcupQatar2022 #B...
# 2  Toda copa a musa volta com a melhor música ❤️☀...
# 3  MARADONA FLYING KNEE \n#FIFAWorldCup #Worldcup...
# 4  With the @FIFAcom #WorldcupQatar2022 underway ...
#
#                                                  url language  \
# 0  https://twitter.com/0KBaila_Q45/status/1596719...       in
# 1  https://twitter.com/SoheBoss/status/1596719678...      qme
# 2  https://twitter.com/AdrielVilla77/status/15967...       pt
# 3  https://twitter.com/theUG/status/1596719631317...       en
# 4  https://twitter.com/DeccanChronicle/status/159...       en
#
#                                             hashtags  likes_count  \
# 0                                [WorldcupQatar2022]            0
# 1                       [WorldcupQatar2022, Bitcoin]            0
# 2  [Wakawaka, shakira, CopadoMundo, WorldcupQatar...            0
# 3                  [FIFAWorldCup, WorldcupQatar2022]            0
# 4                   [WorldcupQatar2022, Inoxcinemas]            0
#
#    reply_count  retweet_count  quote_count  \
# 0            0              0            0
# 1            0              0            0
# 2            0              0            0
# 3            0              0            0
# 4            0              0            0
#
#                                      mentioned_users coordinates place  \
# 0                                               None        None  None
# 1  [https://twitter.com/NeblioTeam, https://twitt...        None  None
# 2                                               None        None  None
# 3                                               None        None  None
# 4                      [https://twitter.com/FIFAcom]        None  None
#
#   cashtags                                              media  \
# 0     None                                               None
# 1     None                                               None
# 2     None  [Video(thumbnailUrl='https://pbs.twimg.com/ext...
# 3     None  [Video(thumbnailUrl='https://pbs.twimg.com/ext...
# 4     None                                               None
#
#                                          tweet_clean
# 0  Apakah Argentina bisa melaju ke final dan MESS...
# 1  @NeblioTeam @TerraRebels #WorldcupQatar2022 #B...
# 2  Toda copa a musa volta com a melhor música ❤️☀...
# 3  MARADONA FLYING KNEE \n#FIFAWorldCup #Worldcup...
# 4  With the @FIFAcom #WorldcupQatar2022 underway ...

# %% [markdown]
# ## Lowercase texts

# %% [markdown]
# Part of the normalization is to put all the texts in lowercase (or uppercase), this can be used later, for example, to do a word count.
#
# ⚠️ Note: When doing this there is a risk of losing contextual information; For example, within a tweet when someone writes a specific word in upper case and the rest in lower case, this leads to a greater importance or increase in tone of voice.

# %%
# cambiar los tweets a letras minúsculas
df['tweet_clean'] = df['tweet_clean'].apply((lambda x: x.lower()))
df.head()
# Out:
#           username                      date                   id  \
# 0      0KBaila_Q45 2022-11-27 04:16:55+00:00  1596719695595732993
# 1         SoheBoss 2022-11-27 04:16:51+00:00  1596719678050607104
# 2    AdrielVilla77 2022-11-27 04:16:48+00:00  1596719666172289024
# 3            theUG 2022-11-27 04:16:40+00:00  1596719631317729282
# 4  DeccanChronicle 2022-11-27 04:16:36+00:00  1596719612984692736
#
#                                              content  \
# 0  Apakah Argentina bisa melaju ke final dan MESS...
# 1  @NeblioTeam @TerraRebels #WorldcupQatar2022 #B...
# 2  Toda copa a musa volta com a melhor música ❤️☀...
# 3  MARADONA FLYING KNEE \n#FIFAWorldCup #Worldcup...
# 4  With the @FIFAcom #WorldcupQatar2022 underway ...
#
#                                                  url language  \
# 0  https://twitter.com/0KBaila_Q45/status/1596719...       in
# 1  https://twitter.com/SoheBoss/status/1596719678...      qme
# 2  https://twitter.com/AdrielVilla77/status/15967...       pt
# 3  https://twitter.com/theUG/status/1596719631317...       en
# 4  https://twitter.com/DeccanChronicle/status/159...       en
#
#                                             hashtags  likes_count  \
# 0                                [WorldcupQatar2022]            0
# 1                       [WorldcupQatar2022, Bitcoin]            0
# 2  [Wakawaka, shakira, CopadoMundo, WorldcupQatar...            0
# 3                  [FIFAWorldCup, WorldcupQatar2022]            0
# 4                   [WorldcupQatar2022, Inoxcinemas]            0
#
#    reply_count  retweet_count  quote_count  \
# 0            0              0            0
# 1            0              0            0
# 2            0              0            0
# 3            0              0            0
# 4            0              0            0
#
#                                      mentioned_users coordinates place  \
# 0                                               None        None  None
# 1  [https://twitter.com/NeblioTeam, https://twitt...        None  None
# 2                                               None        None  None
# 3                                               None        None  None
# 4                      [https://twitter.com/FIFAcom]        None  None
#
#   cashtags                                              media  \
# 0     None                                               None
# 1     None                                               None
# 2     None  [Video(thumbnailUrl='https://pbs.twimg.com/ext...
# 3     None  [Video(thumbnailUrl='https://pbs.twimg.com/ext...
# 4     None                                               None
#
#                                          tweet_clean
# 0  apakah argentina bisa melaju ke final dan mess...
# 1  @neblioteam @terrarebels #worldcupqatar2022 #b...
# 2  toda copa a musa volta com a melhor música ❤️☀...
# 3  maradona flying knee \n#fifaworldcup #worldcup...
# 4  with the @fifacom #worldcupqatar2022 underway ...

# %% [markdown]
# ## Tokenization

# %%
# getting the tokens per tweet
df['tweet_clean'] = df['tweet_clean'].apply(lambda x: x.rsplit())
df.head()
# Out:
#           username                      date                   id  \
# 0      0KBaila_Q45 2022-11-27 04:16:55+00:00  1596719695595732993
# 1         SoheBoss 2022-11-27 04:16:51+00:00  1596719678050607104
# 2    AdrielVilla77 2022-11-27 04:16:48+00:00  1596719666172289024
# 3            theUG 2022-11-27 04:16:40+00:00  1596719631317729282
# 4  DeccanChronicle 2022-11-27 04:16:36+00:00  1596719612984692736
#
#                                              content  \
# 0  Apakah Argentina bisa melaju ke final dan MESS...
# 1  @NeblioTeam @TerraRebels #WorldcupQatar2022 #B...
# 2  Toda copa a musa volta com a melhor música ❤️☀...
# 3  MARADONA FLYING KNEE \n#FIFAWorldCup #Worldcup...
# 4  With the @FIFAcom #WorldcupQatar2022 underway ...
#
#                                                  url language  \
# 0  https://twitter.com/0KBaila_Q45/status/1596719...       in
# 1  https://twitter.com/SoheBoss/status/1596719678...      qme
# 2  https://twitter.com/AdrielVilla77/status/15967...       pt
# 3  https://twitter.com/theUG/status/1596719631317...       en
# 4  https://twitter.com/DeccanChronicle/status/159...       en
#
#                                             hashtags  likes_count  \
# 0                                [WorldcupQatar2022]            0
# 1                       [WorldcupQatar2022, Bitcoin]            0
# 2  [Wakawaka, shakira, CopadoMundo, WorldcupQatar...            0
# 3                  [FIFAWorldCup, WorldcupQatar2022]            0
# 4                   [WorldcupQatar2022, Inoxcinemas]            0
#
#    reply_count  retweet_count  quote_count  \
# 0            0              0            0
# 1            0              0            0
# 2            0              0            0
# 3            0              0            0
# 4            0              0            0
#
#                                      mentioned_users coordinates place  \
# 0                                               None        None  None
# 1  [https://twitter.com/NeblioTeam, https://twitt...        None  None
# 2                                               None        None  None
# 3                                               None        None  None
# 4                      [https://twitter.com/FIFAcom]        None  None
#
#   cashtags                                              media  \
# 0     None                                               None
# 1     None                                               None
# 2     None  [Video(thumbnailUrl='https://pbs.twimg.com/ext...
# 3     None  [Video(thumbnailUrl='https://pbs.twimg.com/ext...
# 4     None                                               None
#
#                                          tweet_clean
# 0  [apakah, argentina, bisa, melaju, ke, final, d...
# 1  [@neblioteam, @terrarebels, #worldcupqatar2022...
# 2  [toda, copa, a, musa, volta, com, a, melhor, m...
# 3  [maradona, flying, knee, #fifaworldcup, #world...
# 4  [with, the, @fifacom, #worldcupqatar2022, unde...
